# %%
import pandas as pd

# %%
engagement = pd.read_csv('takehome_user_engagement.csv',encoding = "ISO-8859-1")
users = pd.read_csv('takehome_users.csv',encoding = "ISO-8859-1")

# %%
engagement.time_stamp = pd.to_datetime(engagement.time_stamp)

# %%
users
# Out:
#        object_id        creation_time                 name  \
# 0              1  2014-04-22 03:53:30       Clausen August
# 1              2  2013-11-15 03:45:04        Poole Matthew
# 2              3  2013-03-19 23:14:52    Bottrill Mitchell
# 3              4  2013-05-21 08:09:28      Clausen Nicklas
# 4              5  2013-01-17 10:14:20            Raw Grace
# 5              6  2013-12-17 03:37:06        Cunha Eduardo
# 6              7  2012-12-16 13:24:32         Sewell Tyler
# 7              8  2013-07-31 05:34:02    Hamilton Danielle
# 8              9  2013-11-05 04:04:24           Amsel Paul
# 9             10  2013-01-16 22:08:03         Santos Carla
# 10            11  2013-12-26 03:55:54       Paulsen Malthe
# 11            12  2014-04-17 23:48:38      Mathiesen Lærke
# 12            13  2014-03-30 16:19:38        Fry Alexander
# 13            14  2012-10-11 16:14:33          Rivera Bret
# 14            15  2013-07-16 21:33:54          Theiss Ralf
# ...

# %%
byday = engagement.groupby(['user_id',pd.Grouper(key='time_stamp',freq='1d')]).agg('count')

# %%
byuser = engagement.groupby('user_id').agg('count')

# %%
for user_id in byday:
    if

# %%
byday
# Out:
#                     visited
# user_id time_stamp
# 1       2014-04-22        1
# 2       2013-11-15        1
#         2013-11-29        1
#         2013-12-09        1
#         2013-12-25        1
#         2013-12-31        1
#         2014-01-08        1
#         2014-02-03        1
#         2014-02-08        1
#         2014-02-09        1
#         2014-02-13        1
#         2014-02-16        1
#         2014-03-09        1
#         2014-03-13        1
#         2014-03-31        1
# 3       2013-03-19        1
# 4       2013-05-22        1
# 5       2013-01-22        1
# 6       2013-12-19        1
# 7       2012-12-20        1
# 10      2013-01-16        1
#         2013-01-22        1
#         2013-01-30        1
#         2013-02-04        1
#         2013-02-06        1
#         2013-02-14        1
#         2013-02-17        1
#         2013-02-19        1
#         2013-02-26        1
#         2013-03-01        1
# ...                     ...
# ...
